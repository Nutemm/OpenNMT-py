# %%
import pandas as pd
from nltk.tokenize import word_tokenize
import re

# %%
train_examples = pd.read_csv("train.csv", names=['class', 'title', 'text'])

# %%
test_examples = pd.read_csv("test.csv", names=['class', 'title', 'text'])

# %%
#train_examples[train_examples['3']==2]

# %% [markdown]
# ### CREATE DATASET FOR OPEN-NMT

# %%
train_examples = train_examples.sample(frac=1)

# %%
examples = pd.concat([train_examples, test_examples])

# %%
classes = list(examples['class'])
titles = list(examples['title'])
texts = list(examples['text'])

# %%
def clean_title(title):
    title = title.replace("\\", " ")
    
    #Remove last part of title (name of journal)
    title = title.strip()
    if title[-1] == ')':
        position_left_parenthesis = title.rfind("(")
        title = title[:position_left_parenthesis]
    title = title.lower()
    title = " ".join(word_tokenize(title))
    title = title.replace("& lt ; b & gt ; ... & lt ; /b & gt ;", "")
    title = title.strip()

    return title

# %%
def clean_text(text):
    text = text.replace("\\", " ")
    text = text.replace('#39;s', "'")

    #Remove first part of text (name of journal or date)
    text = text.split(" - ",1)
    if len(text)>1 and len(text[0]) < len(text[1]):
        text = text[1]
    else:
        text = text[0]
        
    text = text.split(" -- ",1)
    if len(text)>1 and len(text[0]) < len(text[1]):
        text = text[1]
    else:
        text = text[0]
    
    text = text.lower()
    text = " ".join(word_tokenize(text))
    text = text.replace("#", "")
    text = text.replace("& lt ;", " ")
    text = text.replace("& gt ;", " ")
    return text

# %%
titles = [clean_title(title) for title in titles]

# %%
texts = [clean_text(text) for text in texts]

# %%
titles
# Out:
# ['oracle sex suit winner seeks $ 679,000 , apology',
#  'oil worries remain , despite price slide',
#  'mozilla gains five points , ie slips five',
#  'touch wood',
#  'uk hostage # 39 ; in hands of new group # 39 ;',
#  'blackberry infringement ruling upheld',
#  'greene seeks revenge for olympic defeat',
#  'building green',
#  'google , 5 big libraries team to offer books',
#  "philly folly on packers ' minds",
#  'advice to microsoft : learn to love linux',
#  'los angeles dodgers team report - september 26',
#  'hoops team rebounds',
#  'pg amp ; e talks to residents about powerline project',
#  'bryant accuses malone of hitting on wife',
#  'nasa chief o # 39 ; keefe resigns',
#  'report : gamecocks to name spurrier new head coach tuesday',
#  'dow knocked lower by merck # 39 ; s drug recall',
#  'most home pc users at risk for attack',
#  'senior chinese leader to visit n.korea next week',
#  'bringing order to the fungus among us',
#  'cambodia # 39 ; s new king , norodom sihamoni , arrives home',
#  'this travel search site could go far',
#  'shell to spend $ 45b us to replace reserves while selling non-core',
#  'myanmar completes release of 9,000 prison inmates',
#  'jobless claims rise to three-week high',
#  'newly released lsb 2.0 gains powerful industry ally',
#  'injured beckham cuts short training',
#  'tennis : davis cup proves hewitt # 39 ; s home court',
#  'arsenal draw 2-2 with panathinaikos',
#  'pekerman revealed as argentina coach',
#  'human stem cells show potential for eye repair',
#  'nba wrap : heat tame bobcats to extend winning streak',
#  'tszyu in thumping win',
#  'violence prompts curfew in liberia capital',
#  'reasons to like four seasons',
#  'hungary bans sale of paprika',
#  'click-less phishing scam steals passwords',
#  'us expected to hike interest rates today',
#  'german teenager indicted over sasser worm',
#  'gronkjaer to wear number 11 with atletico madrid',
#  'temasek reveals earnings for first time',
#  'hungary wins gold in olympic water polo',
#  'fujitsu siemens computers launches the lifebook t4010',
#  'us firms prove green credentials',
#  'price of oil rises despite loans from us reserve',
#  'peoplesoft spurns latest oracle offer , says shareholders unmoved',
#  'forget england , india are no 2 , says merv',
#  'silver to mcgee , mactier into final',
#  'iraqi president delays trip to france over hostage crisis',
#  'four die in suicide attack',
#  'webex , genesys enhance conferencing services',
#  'news : bagle variant outstrips google-bashing worm',
#  'antiterror change urged in europe',
#  'stocks look to nudge higher ; oil dips',
#  'afghan poll crisis subsides as karzai rivals back off',
#  'becks and co get the grief as real boo boys vent frustrations',
#  'paisley rules out devolution deal',
#  '$ 5 million quot ; shortfall quot ; in access accounts ; bnz freezes some access',
#  'red hat drafts sun exec for desktop linux push',
#  'no word on trapped china miners',
#  'delegates urge al-sadr to leave shrine',
#  'parked in a desert , waiting out the winter of life',
#  'adobe acrobat 7 unveiled',
#  'call to arms : marino and young head hof # 39 ; s nomination list',
#  'intel , hp to commercialize planetlab',
#  'world bank : cambodia economy to slow down',
#  'airbus to launch a350 to rival boeing 7e7',
#  'tech.gov : barriers to free wi-fi',
#  'gaza violence dents peace hopes',
#  "boston 's technology takes corporate , not consumer , tilt",
#  'emc nabs former ibm grid guru for cto position',
#  'nepal awaits maoist response to call for talks :',
#  "oracle vows 'oversupport ' for peoplesoft customers",
#  'doctors try to help body grow its own bypasses',
#  'suicide bomber kills at least 18 in pakistani mosque',
#  'marquis focused on game 4 start',
#  'study : americans happier with their pcs',
#  'hamm admits he will be shocked if he loses gold',
#  'trade paying dividends in boston',
#  'kerio partners must pass rigorous exam to carry new serverfirewall',
#  'security concerns put msn messenger beta on hold',
#  'f1 rivals line up on the grid',
#  'iran says it has produced gas for nuclear enrichment',
#  'baldini joins legends of marathon',
#  "rockets ' yao goes back to school in china",
#  'cisco systems acquires p-cube',
#  '24 dead in gaza strip fighting',
#  'fed seen boosting rates despite worries',
#  'alex regrets for the misses',
#  'uspto trims fat from microsoft patents',
#  'new bird species found in philippines',
#  'wenger backs lehmann for germany',
#  'film industry to sue online pirates',
#  'dsl wars come down to a battle of the bundles',
#  'crazy john # 39 ; s gone reckless : latham',
#  'dollar firm vs yen on jobs news',
#  'symbol , proxim settle wlan patent case',
#  'apple unwraps new imac g5s at paris show',
#  'mount st. helens may take weeks to erupt',
#  '2 un peacekeepers shot in haiti',
#  'afghans need time , world # 39 ; s continued help',
#  'at amp ; t release ogo',
#  'burress : pats still roughing up receivers',
#  'chrysler recalling 240,100 minivans',
#  'ferdinand excited by return',
#  'fcc says it extended discounted phone-line rates',
#  'beltre helps lift dodgers past rockies',
#  'ankiel throws scoreless inning for cards',
#  'hamas member escapes damascus bomb blast',
#  'wal-mart expects bumper christmas',
#  'eagles teach , lions learn',
#  'vendors announce new web services specification',
#  'arsenal reserve goalkeeper graham stack charged with rape',
#  'braves and astros open second day of playoffs wednesday',
#  'scientists create electronic eye for the blind',
#  'darfur governor says rebels attempted coup',
#  'us revises its strategy on sudan , seeks un aid if peace deal signed',
#  "the n.h.l . must figure out if it 's certain on cost certainty",
#  'us mulls ending ban on airplane cell-phone calls',
#  'blown save in ninth leads to loss on homer in 12th',
#  'in j amp ; k , patil greeted with snubs , violence',
#  'chelsea warning to champions',
#  'lockout looms as nhl players # 39 ; contract offer rejected',
#  'savage blow for blues',
#  'baseball-schilling gives red sox 2-0 world series lead',
#  'cornice countersues seagate',
#  'tom brokaw : events and leaders of our time',
#  'millwall , ferencvaros fans clash',
#  'dutch launch international hunt for syrian suspect',
#  'japan stocks dip down , oil concerns weigh',
#  'woburn back in fine form',
#  'think before you click to avoid viruses and scams',
#  'canadian poolcrasher prompts tighter security',
#  'jaguar workers urged to fight closure',
#  'citigroup slides on merrill downgrade',
#  'holiday sales forecasted in new ways',
#  'becks row rumbles on',
#  'juncker gets post as # 39 ; mr. euro # 39 ;',
#  'crude oil prices rise on concerns over labor unrest in nigeria',
#  'spaceport mum on frances shuttle delays',
#  'sf # 39 ; bringing bug device to talks # 39 ;',
#  'otellini to become intel # 39 ; s ceo',
#  'us agrees to halliburton inquiry',
#  'smith inactive for arizona vs. lions',
#  'a push to restrict sales of video games',
#  'six dead as nepal rebels vow to step up blockade',
#  'philips cautious despite profits',
#  "yankees ' 100th clinches division",
#  'losing 60 years of experience',
#  'asian stock markets cheer quot ; pro-business quot ; bush lead',
#  'russia will continue its nuclear energy cooperation with iran',
#  'analysts see fda spurning new merck arthritis drug',
#  "science 's budding stars shine",
#  'federer rolls on',
#  'megson drafts in lawyers to settle contract',
#  "us sale boosts waterford 's profit",
#  'educational and funny research honored',
#  'will oil light a fire under inflation ?',
#  'returning to football helps faulk carry on',
#  'astronomers predict red moon during total lunar eclipse',
#  'chinese pottery yields leftovers of stone age happy hour',
#  'kim lands maiden victory',
#  'game day preview game time : 7:00 pm',
#  'raytheon seeks to change board election',
#  'h r block faces fraud over enron bonds',
#  'australia warns of possible indonesia hotel attack',
#  'miller # 39 ; s winning streak ends at three as goergl wins super g',
#  'oil extends two-day fall as china # 39 ; s rate rise may cut demand',
#  'lehman agrees to pay $ 222.5m to settle enron suit',
#  'south asian pms to hold key talks',
#  'powell seeks seoul help on n.korea',
#  'kentucky sen. bunning in flap over his health',
#  'lampard confident',
#  'vietnam to create more favorable conditions for foreign investors',
#  'update 1 : indian telecom buys tyco network assets',
#  '9/11 commissioner : threat of airplane suicide bombing has',
#  'colts # 39 ; james listed as doubtful for sunday',
#  "brits , french , germans give iran 'last chance '",
#  'straw upbeat over iraq elections',
#  "bush , kerry do n't worry about tech",
#  'no . 19 alabama tops minnesota 78-72',
#  'comdial extends sip to branch offices',
#  'peru tv staff quit in toledo row',
#  "hp 's fiorina stood up by argentina 's president",
#  'union , d.c. hotels recess negotiations',
#  'burns puts himself in scotland frame',
#  'brown packs pint-sized wallop for georgia',
#  'pats set nfl record with 19th straight win',
#  'yahoo ! shows live traffic conditions',
#  'abn amro # 39 ; s q3 profits up 26',
#  'iraqi envoy backs raid on fallujah',
#  'all bio systems are go',
#  'don # 39 ; t let children buy bonds # 39 ; pitch',
#  'presidential campaign gathers steam in final stretch to november 2',
#  'bangladesh crumble',
#  'bombardier axes 2,000 ; another 1,200 jobs at risk',
#  'powerful bomb blasts shake central baghdad',
#  "europe , u.s. in deadlock on climate talks ' last day",
#  'euro slips , yen steady in start to 2005',
#  'equity analysts : record inflows may lift stocks',
#  'two killed in bomb blast in bangladesh',
#  'colombian indians want time to forget their land',
#  'tech workers stay put as economy perks up',
#  'accused pair to tell their side of story',
#  'yahoo unveils personal search',
#  'treasuries edge narrowly higher at midday',
#  'feds consider putting a bounty on spammers # 39 ; heads',
#  'irs relaxes rules on business tax filing',
#  'reuters looks to make india job hub',
#  'fate of us iraq war ally hangs in balance as australians vote',
#  'back to the roots',
#  'blue jays rookie pitcher handcuffs yankees',
#  'irish invite for de lima',
#  'rockies name third base coach',
#  'us leading economic index fall for third straight month in august',
#  'city taken off moody # 39 ; s watch list',
#  'rim infringed ntp patents , appeal court rules',
#  'karzai sworn in as first democratically elected afghan president',
#  'fallujah focus for us forces',
#  'branch return breathtaking',
#  "intel says it 's recovered from missteps",
#  'pacquiao has truly arrived',
#  'us doctor says evacuations , body armor have helped save lives in',
#  'update : investors favor james hardie despite findings',
#  'soy fungus spotted in us',
#  'ibm enhances support for isvs',
#  'breakaway tamil tiger launches political party',
#  'brief : iron mountain snaps up backup software vendor',
#  'eu reportedly closer to settling antitrust case with coca-cola',
#  'clash of the tech titans',
#  'patience could prove a virtue for australia',
#  'google goes mobile with sms',
#  "yahoo 's home page gets functional facelift",
#  'world # 39 ; s largest atom-smashing lab turns 50',
#  'williams to take second look at heidfeld .',
#  'mukesh replies in the name of the father',
#  'not another soviet union',
#  'three dead in israeli air strike in west bank',
#  'repco buys alesco # 39 ; s auto business for a $ 89.5 million',
#  'bombing kills 2 in thailand ; villagers bury 22 who died in custody',
#  'first us spam conviction',
#  'mbeki into new discussions in ivory coast , eu urges peace',
#  'bank of america to cut 4,500 more jobs',
#  'debating the evidence on gulf war illnesses',
#  'caddie : woods to return to top of game',
#  'homer sinks indians',
#  'r. clark may start',
#  'powell may push china for information on new york times researcher',
#  'ford posts profit ; loses money in autos',
#  'apple opens canadian itunes store',
#  'update 8 : shares of robert mondavi surge 30 percent',
#  'dollar inches up , falls seen again',
#  'via develops twin-core processor',
#  'wedding rumours abuzz in barbados',
#  'bush remembers 9/11 with quiet observance',
#  'warne breaks test wickets record',
#  "powell says he wo n't run for office",
#  'india need not worry over oil price rise for now : adb',
#  'alert yale defense keeps green winless',
#  'profits increase as bayer revamps',
#  'novell counters microsoft # 39 ; s linux # 39 ; facts # 39 ; with # 39 ; truth # 39 ;',
#  'senior officers threaten to quit israeli army in settlements rift',
#  'e-voting firms reveal software to feds',
#  'dup to meet blair for talks',
#  'toyota , partner to invest $ 461 mln in china venture',
#  'irish priest who disrupted games acquitted of abuse',
#  'israel releases senior hamas leader',
#  'us airways : the fliers amp ; stockholders',
#  'the week # 39 ; s business : putting black behind bars or recovering money',
#  'henin-hardenne beats mauresmo ; gonzalez # 39 ; s long day yields gold',
#  'hicks muse pays $ 194 million for conagra unit',
#  'italy prepared to pull troops out of iraq if baghdad government asks : fm',
#  'microsoft ceo meets indian prime minister',
#  "'bin laden ' tape urges oil attack",
#  'pakistan in # 39 ; al-qaeda # 39 ; arrests',
#  'virginia tech seeks luster against usc',
#  'montgomery hearing set for june in san francisco',
#  'german recycling violates eu law',
#  'by signing renteria , red sox finally make a big splash',
#  'brazil union backs 10 pay raise from automakers , estado says',
#  'not looking down at umass',
#  'health issue , lack of fervor made h. brown leave',
#  'appeals court denies moussaoui hearing',
#  'judge could kill united union contract',
#  'safin downs hewitt at paris masters',
#  'half-life 2 released',
#  'philip morris to invest $ 200m in cabarrus plant',
#  'valencia chief exonerates ranieri',
#  'annika seeking eighth win of season',
#  'australian train derailment injures 79',
#  'liu , jones pull out of berlin meeting',
#  'quick read on your genetics',
#  'pirates # 39 ; bay national league rookie of the year',
#  '3 fugitive muslim militants suspected in jakarta attack',
#  'iaea chief says world getting impatient with n.korea',
#  'oceans to rise one meter by 2100-arctic expert',
#  'new mydoom worm exploits ie flaw',
#  'ing reveals improper trading case details',
#  'stocks seen lower , weighed down by oil',
#  'french minister says release of hostages in iraq still possible',
#  'a slugger # 39 ; s paradise',
#  'car bombs in iraq kill at least 42 , wound 140',
#  'a bit of a head-scratcher',
#  'court panel skeptical about penalty sought against tobacco',
#  'australia , indonesia consider defense pact',
#  'invesco , aim agree to # 36 ; 450 mln settlement',
#  'peoplesoft board kos oracle takeover bid',
#  'airline adds $ 500 million to earlier estimate',
#  'open sourcers revolt against microsoft antispam plan',
#  'amazon unveils its search engine',
#  'mcafee aims to rid smbs of virus and spam',
#  'rumsfeld visits central america',
#  'soldier sentenced for iraq prison abuse',
#  'italy voices outrage at execution of hostage',
#  'hamza quizzed over terrorism',
#  'merrill cuts citigroup , shares drop',
#  'big ten gears defenses to stop run',
#  'will microsoft makes its browser better ?',
#  'vail resorts # 39 ; loss widens to us $ 31.5 million , real estate revenue',
#  'news corp. enters # 39 ; new era # 39 ;',
#  'guantnamo detainee says in letter that he was tortured',
#  "hp 's fiorina : sometimes it spending is a 'bad thing '",
#  'senate passes scaled-back copyright bill',
#  'krispy kreme says s.e.c . steps up its probe',
#  "'enron of kansas ' trial begins",
#  'russia successfully launches soyuz 2-1a rocket',
#  'update 5 : karstadtquell to sell nearly half stores',
#  'nuggets anthony denies marijuana was his',
#  'microsoft seizes pda market lead from palmsource',
#  'symantec agrees to buy veritas software',
#  'japan airlines cancels flights as typhoon heads to main islands',
#  "cleric at arafat 's bedside during 'final phase '",
#  'european soccer to investigate racism',
#  'virgin electronics unveils music player',
#  'secret service busts cyber gangs',
#  'network adds delay to nascar telecasts',
#  'vogts remains optimistic',
#  'price of heating oil in state surges',
#  'isiah points to backcourt in rebuilding knicks',
#  'uk company to buy infonet for $ 965m',
#  "bush pledges to aid colombia 's drug fight",
#  "microsoft 's answer to phishing : two ids",
#  'stocks rise on strong retail sales report',
#  'pope returns icon to russia',
#  'wounded servicemen describe fallujah fight',
#  'chinese handset makers led chip slowdown',
#  'microsoft readies windows server 2003 r2 beta',
#  'chain store sales mixed in latest week',
#  'australia pressured for nz law change',
#  'amd debuts low-cost net device',
#  'microsoft joins search party',
#  'race remains a difficult issue for many workers at kodak',
#  'mmo2 signs japanese internet deal',
#  'powell spurns north korea demand on talks',
#  'tentative alaska land swap raises drilling fears',
#  'mlb all-stars rally past japan',
#  'benign inflation lifts bonds',
#  'advertising # 39 ; s interpublic sees loss widen',
#  'news corp move to us gets reluctant boost from major shareholder',
#  'uk opposition figure seeks troop info',
#  'ibm rolls out arrays , tries again on iscsi',
#  'israel bus blast said mechanical problem',
#  "clarke 's x-ray specs - police swoops , detectors for schools",
#  'dreamworks postpones # 39 ; shrek 3 # 39 ;',
#  'ukraine rivals ok vote reforms for rematch',
#  'sun revisits its telecom roots',
#  'arizona # 39 ; s stoops not enjoying first taste of losing',
#  'angels suspend guillen for rest of season',
#  'pepsico profit rises on tax benefits',
#  'better late than never : auburn climbs into mix',
#  'stem cells feed brain tumors',
#  'europe calls on israel to maintain self control , al describes',
#  'red sox sign wells ; pavano courts yanks',
#  'troops deployed after indian terror attacks',
#  'convictions in enron fraud trial',
#  'suicide attack kills 2 in israel ; 16 hurt',
#  'scuffle feeds harry # 39 ; s party boy image',
#  'the broadband market rises in the uk',
#  'air societal concerns to fill innovation gaps',
#  'greek police hand kenteris crash report to prosecutor',
#  'foolproof performance',
#  'dollar weak , asia stocks down',
#  'toyota sign jordan deal',
#  'kite rallies for share of lead at sbc championship',
#  'israeli cabinet approves payouts for gaza settlers',
#  'gateway alumnus resurfaces at hp',
#  'elan settles suit and sec probe',
#  'lockheed martin profit jumps 41 in quarter',
#  'notorious indian criminal killed',
#  "it 's all about the ipod",
#  'update 1-gibernau cruises to victory at czech gp',
#  'the hardest-working woman in the tv biz',
#  'army reservist in iraq pleads guilty in prisoner abuse court',
#  'toys r us fights to stay afloat in toy business',
#  'so what is it about win2k security ms won # 39 ; t enhance ?',
#  'si.com',
#  'loonie soars on expected rates hike',
#  'consumer confidence hits 7-month low',
#  'chain store sales rise in the oct 9 week',
#  'fijian holds firm in lumber',
#  'astrazeneca # 39 ; s nexium gets us approval for new use',
#  'us , australia team up to protect vulnerable reefs',
#  'palestinian elections committee accuses israel of interference',
#  'update 2 : top citigroup executives swap jobs',
#  'nortel sees lower 3rd-quarter revenue',
#  'us launches air raids on fallujah , aid worker # 39 ; s captors give 48',
#  'walgreen profit rises 30.5 pct , shares up',
#  'blair : iraq report shows sanction problems',
#  'at least 2 killed in car bombing in iraq',
#  'musharraf not decided on quitting army post : us',
#  "falcons ' crumpler , price miss practice",
#  'saboteurs blow up pipeline',
#  'aziz elected pak pm amid boycott by oppn',
#  'tributes flow for keith miller',
#  'rockets rain , truck bomb found ahead of afghan vote',
#  'china sees heavy investment in argentina in decade',
#  'canas beats burgsmuller to capture shanghai title',
#  'thechat',
#  'arab league chief : iraq getting tense',
#  'golf : ryder cup pairings named',
#  'hypertransport consortium approves htx expansion spec',
#  'stocks edge down , hurt by weak dollar',
#  'rustu prepared for united',
#  'tourist hostages freed from inca temple in peru',
#  'russia to take concrete steps in economic cooperation with',
#  'bush says us will tap emergency oil supplies',
#  'mets close in on deals with benson , leiter',
#  'microsoft offers users legal protection',
#  'canada confirms mad cow case',
#  'florida st. boots wake',
#  'hong kong chokes under thick smog',
#  'dollar falls to fresh low vs euro',
#  'blue chips fall on commodity , oil stocks',
#  'stocks : upbeat orders data bolster wall street',
#  'sony , nvidia make playstation collaboration official',
#  'auto industry report : ford ceo has new goal',
#  'oil rises on opec cut talk , saudi attack',
#  'intel lops pentium 4 prices',
#  'afghans say to kill un hostage if demands not met',
#  'crude prices set n.y. record',
#  'iraq probes possible security breach over killings',
#  'fla. county to replace absentee ballots',
#  'ibm and amd partnership extended through 2008',
#  'spurs appoint martin jol',
#  'tamil tigers are unlikely to change their stripes ( news analysis ) :',
#  'americans forces strike fallujah',
#  'students heckle iranian president',
#  'bidder misses fan pier payment',
#  'delta releases new details on up to 6,900 job cuts',
#  'report : icc demands explanation from zimbabwe govt',
#  'falmouth blanks dartmouth',
#  'for want of a photo , agreement is lost',
#  '2 car bombings in iraq kill 41 , many children',
#  'kidnapped cnn producer freed',
#  'strike threat to christmas post',
#  'delay supporters move to protect his spot',
#  'arafat in intensive care',
#  'hearing to be held friday in oakland',
#  'n. korea may be preparing missile launch',
#  'invest in housing without buying a home',
#  'colorado may be blueprint for democrats',
#  'liberty media revenues , cash flow up',
#  'us expecting another interest rate hike',
#  'frank quattrone is a bad man',
#  'wal-mart preliminary same-store sales up',
#  'texas roadhouse shares up on market debut',
#  'british tycoon plans for commercial space flights',
#  "francona kept sox ' snags sewn up",
#  'fox joins group promoting new dvd format',
#  'berlusconi blasts eu rejection',
#  'south africa to take pulse of its environment',
#  'ethical fair trade - you knew it made sense until ms embraced it',
#  'eli # 39 ; s time coming , but kurt # 39 ; s is here',
#  'nokia makes good on business phones',
#  'iraqi christians struggle to stay',
#  'shirking the blame ?',
#  'switch problem on genesis craft',
#  'china vows tougher penalties , up to life in prison , for internet',
#  'fewer people paying for music downloads - npd',
#  'update 1-univ . of calif. reaches settlement with lehman',
#  'iraq group kidnaps four , including an american , afp reports',
#  'oil above # 36 ; 41 as saudi cuts supplies',
#  'calpers unveils managmement fees in settlement of open records',
#  'fda orders strong antidepressant warnings',
#  'sanctions will mean war : n korea',
#  'ca officially taps swainson for ceo job delays ca world',
#  'at amp ; t launches the messaging ogo',
#  'in mozambique , vote to bring change at top',
#  'tape of bigley # 39 ; s assassination posted on website',
#  'thatcher posts bail to end s.africa house arrest',
#  'google tests personal search service',
#  'update 9 : crude futures hold above $ 50',
#  'business news for technology leaders daimlerchrysler , gm team up',
#  'tennis : nalbandian to meet novak in basel final',
#  'no . 13 louisville 85 , n. carolina a amp ; t 51',
#  'wall street set for steady open',
#  'ahold to sell off its spanish holdings',
#  'europe clears oracle takeover',
#  'myanmar among new asia-europe forum members',
#  'regulators seek information from 2 firms',
#  'volkswagen to open assembly plant in uae',
#  'keane and vieira in ot fitness race',
#  "ca looks to move on after kumar 's indictment",
#  'survey shows what pleases new-home buyers',
#  'samsung raises flash memory bar',
#  'illinois takes top ranking in ap poll',
#  'at amp ; t launches new e-mail service',
#  'profits , revenue climb at rambus',
#  'sports roundup : hockey player , 31 , dies',
#  'france remembers wwii riviera mission',
#  'pakistani militant farooqi had links with top al-qaeda leaders',
#  'revealed : why the fear factor runs with the pack',
#  'pfizer to sponsor large new celebrex trial',
#  'december 13 titan flyby prelude to landing',
#  'imf says russia must save energy windfall',
#  'us , eu take to skies in battle of the giants',
#  'seeded players costa , davidenko out of romanian open',
#  'munich set to approve linux despite patent worries',
#  'google rolls out search product for scholars',
#  'no . 24 ariz. beats rice in preseason wnit',
#  'eu stops clock on contentguard investigation',
#  'eu expected to approve talks with turkey',
#  'update 1-argentina files $ 100 bln restructuring with us sec',
#  'milan rivals steamroller spain # 39 ; s finest',
#  'update 3-amd posts profit , sees sales growth ; shares rise',
#  'russia looking to moon and beyond for future space base in 2020',
#  'myskinia heads all-russian final',
#  'big sam slams souey slur',
#  'sharon says gaza settlers to leave homes',
#  'israel , palestinians seek deal to end gaza fighting',
#  'singapore shares end dn on pft-taking ; eucon weak debut-2-',
#  'this lying , sneaky spirit of the games',
#  'bush pushes mlb to address steroid issue',
#  'some firms avoid dent from scandal',
#  'for love of the dance ... a tale of defection',
#  'ibm brand loyalty holds key for lenovo',
#  'linux community steamed over windows piracy report',
#  'mcgregor : back in the us to head broadcom',
#  'festivals may not cheer durable goods makers',
#  'lg.philips to spend $ 5.1 billion on new flat-panel tv factory',
#  'photo 5 of 5 : gadgets galore in old tokyo',
#  "army 's allure has brought ross back to sideline",
#  'militants bomb kashmir mourners , killing one',
#  'australia play game of patience',
#  'shell evacuates staff from nigerian conflict',
#  'surviving the ipo from hell',
#  'china looks outside asia for m a',
#  'oracle readies major app server upgrade',
#  'espn in talks to set up european sports channel',
#  'o2 outlines 3g catch up strategy',
#  'brief : siemens warns of ear damage from loud mobile tune',
#  'crude oil rises to two-week high on heating oil supply concern',
#  'microsoft reports fiscal first-quarter earnings up 11 percent',
#  'interview : australia # 39 ; s evans amp ; tate aims for 10 growth',
#  'new orleans center breaks finger',
#  'arsenal keeper stack charged with rape',
#  'tobacco companies to fight it out in court',
#  'dubai airport building collapses',
#  'e-vote snafu in florida',
#  'terrorists calls for hostage # 39 ; s release',
#  'mlb : chicago white sox 7 , texas 4',
#  'official : 16 killed in russian crisis',
#  'ing canada prices its shares at $ 26 each in $ 907m initial public',
#  'missouri puts school nickname on arena',
#  'in fox they trust : panthers lean on coach to turn around 1-7 start',
#  'hurricane ivan destroys homes in grenada',
#  'deutsche executives retreat to ready a new strategy',
#  'numbers of poor , uninsured rise',
#  'amd # 39 ; s new budget processors',
#  'road to la : hang on a minute !',
#  'hewitt routs gaudio , eases into masters cup semis',
#  "flames ' kiprusoff wins arbitration case",
#  'first look : danger sidekick ii',
#  "france 's renault to invest 570 million dollars in south korea",
#  'ctia shines spotlight on mobile middleware',
#  'irs on search for nebraska residents',
#  'iraqi president on landmark visit to kuwait',
#  'google goes public',
#  'md . researchers growing blue crabs in lab',
#  'bengals win using palmer method',
#  'figuring out the rules for voip',
#  'freescale unveils dual-core powerpc architecture',
#  'harvard facing challenging test',
#  'brazil coach more worried about venezuela than germany',
#  'cancellation of telecast rights constitution bench to hear',
#  'smart-1 eases into orbit around moon',
#  'economy grows at 2.8 rate in the spring',
#  'new chief at kmart',
#  'nba wrap : mcgrady leads rockets to stunning win',
#  'england doubles up poland',
#  'europe aims to close comfortable ryder victory',
#  'ponting doesn # 39 ; t think much of kiwis or winning # 39 ; myth # 39 ;',
#  'militants threaten to kill us , uk hostages in iraq',
#  'nvidia to work on playstation 3 chip',
#  'liquid machines to acquire e-mail company',
#  'amd loses nvidia monopoly',
#  'wells fargo , u.s. bancorp profits rise',
#  'stocks edge higher on retail report',
#  'federer # 39 ; s olympics end unexpectedly early with two losses',
#  'one vacancy could reshape court',
#  "it 's not exclusive , but it 's lucrative : why luxe went online",
#  'for blackberry users , a new way to write',
#  'cmu grad hopes to turn skype # 39 ; s fast-growing internet phone service',
#  'john deere , irobot team on military vehicle',
#  'update 1-werder come from behind for 2-1 away win',
#  "plane crashes wo n't hurt putin in chechen vote",
#  'lilly warns doctors on strattera use',
#  'preview : day six',
#  'shell opens door to links with gazprom',
#  'inbev # 39 ; s labatt to cut 180 jobs , close canada brewery',
#  'polls open in australian general election with contenders in dead heat',
#  'hbos walks away from abbey',
#  'golf : cool hand luke can be top gun',
#  'video game maker acclaim files for bankruptcy',
#  'baseball shock at caminiti death',
#  'nuggets snag win this time',
#  'sun woos wall street with pricing , features',
#  'yankees # 39 ; victory demonstrates jeter # 39 ; s value',
#  'ruiz , byrd , rahman and donald all score wins',
#  'intel 65-nanometer chip to use less power',
#  'amd ships new mobile athlon 64 , 90-nm processors',
#  'house passes tough computer anti-spyware bill',
#  'empty feelings',
#  'salton loss widens , hurt by charges',
#  'pbl punts on macau',
#  'winter storms source of earth # 39 ; s hum : geologists',
#  'commercial pc demand boosts market forecast',
#  'paypal overcomes glitches',
#  'u.n. panel : cambodia could be terror haven',
#  'ten percent birds disappear by 2100 : study',
#  'washington state ferries expands ferryboat wi-fi service',
#  'gutierrez brought new flavor to cereal company',
#  'stocks jump ; insurers , home builders help',
#  'not enough lift for hamman',
#  'q a : sas international chief on global best practices',
#  'shopko reports november retail sales',
#  'japanese grand prix moves on to sunday',
#  'nfl wrap : barber runs over packers as giants win',
#  'mci takes financial charge for q3',
#  'telephone ties bond tigers',
#  'magic # 39 ; s garrity activated from injured list',
#  'reports may indicate n.korea nuclear test-ny times',
#  'microsoft says longhorn to ship in 2006 without winfs',
#  'lynching of agents puts mexico focus on vigilante justice',
#  'sybase releases free express database for linux',
#  'low-cost versions of windows xp unveiled',
#  'liga sat . wrap : barca draw as valencia crisis continues',
#  'first in spam ? please , not that',
#  'nepal asks maoists for talks',
#  'del neri replaces voeller',
#  'sun drafts new quot ; sco-sensitive quot ; open source license',
#  'us consumers anxious about lack of hiring',
#  'russia # 39 ; s yukos seeks protection in us',
#  'new to science , island bird that never flies nest',
#  'drivers need to keep cool',
#  'grin and bear it : manning and james lead colts to another rout',
#  'u.s. plans to divert iraq money',
#  'lyon , man u # 39 ; s ruud put on four-star shows',
#  'martin accuses harper of political cowardice over gay marriage',
#  'white sox sign of dye to two-year contract',
#  'amazin # 39 ; s look to interview dodger coach',
#  'microsoft overhauls its engine',
#  'hutchison arm rules out dividends',
#  'ira must take immediate steps to disarm : n. ireland protestant leader',
#  'enron case prosecutors calling for a single trial',
#  'update 1 : ericsson lands $ 805m contract from china',
#  'microsoft # 39 ; s windows update services looms on the horizon',
#  'daimlerchrysler plans to transfer jobs',
#  'johnson takes bitter-sweet win at martinsville',
#  'linux may power south korean schools',
#  'is your pc safe from viruses and spyware ?',
#  'english league sets standard for european elite',
#  'high oil prices might be a blessing in disguise',
#  'ibm , other vendors accused of cheating e-rate program',
#  'big blue absorbs venetica in move to strengthen information',
#  'davenport back on top of the world',
#  'gm deal : hitch included',
#  'optimism in london , carnage in iraq',
#  'surprise victory for basescu in romania',
#  'hitachi shrinks ipod hard drives',
#  'drivers can wait , says red bull boss purnell',
#  'spaniards garcia , lara lead in spain',
#  'dialysis clinic chain agrees to pay $ 350m',
#  'buckeyes # 39 ; 5 fgs trip wolfpack',
#  'smithfield foods profit more than doubles',
#  'australia # 39 ; s maritime security net stirs concern among neighbors',
#  'mel # 39 ; s sirius decision',
#  'oprah car winners hit with hefty tax',
#  'woods back in familiar spot',
#  'bengals finish strong',
#  'japanese government hopes to allow woman on throne within years',
#  'kobe case full of errors',
#  'mods for doom iii out and aboot',
#  'housing starts surge 6.4 pct . in october',
#  'typhoon kills 66 in japan , deadliest in 22 years',
#  'bird flu may have killed thai tigers -- minister',
#  'burns to stay on as smith agrees four-year deal with scotland',
#  'australia # 39 ; s telstra ceo search may favor outsiders',
#  'nl wrap : grand slam helps giants close on dodgers',
#  'eu , russia fail to reach accord at summit',
#  'critics cite red light monitoring risks',
#  'parliamentary panel to probe beslan tragedy',
#  'wrapup 1-russia , france close in on fed cup final',
#  "us court rejects movie , music makers ' piracy claims",
#  'in paris , a slick maneuver tries to lure tourists to eiffel tower',
#  'one probe to cover fire , death of sub officer',
#  'loss from the jaws of victory painful',
#  'blazers # 39 ; woods in trouble again',
#  'ebay explodes to twice its size',
#  'the week in ipod',
#  'ibm brings high-end storage functions to midrange',
#  'google ipo bidding opens',
#  'pakistan and egypt favourites for world team squash title',
#  'armstrong says he might skip next tour',
#  'burma pm accused',
#  'wal-mart profit rises , raises outlook',
#  'insurance probe bags two more',
#  'stocks higher on drop in oil , fed comments',
#  'siemens unveils cordless phones for skype users',
#  'ibm teams with honda on voice-driven car navigation',
#  'scotsman praised as media urged to keep dafur in spotlight',
#  'gmail accounts vulnerable to xss exploit',
#  'huey exits early',
#  'prep banned from iac',
#  'the nfl is in a league of its own',
#  'epa says enforcement shows results',
#  'apple to unveil special-edition u2 ipod',
#  'us soldier admits killing injured teen',
#  'after busy black friday , shoppers downshift',
#  'pence sees arafat death as opportunity for mideast peace',
#  'symantec upgrades norton security products',
#  'adrenaline junkie phelps losing sleep at night',
#  'kodak to cut jobs in england , france',
#  'republican convention opens as delegates adopt platform',
#  'restitution is ordered in ebay sales',
#  'bill to raise calif. minimum wage advances',
#  'welshman dodd midway leader in china',
#  'alcoa cautions about below-market offer',
#  'bangladesh opposition calls for monday strike',
#  'digital recorders bump old vcrs off the shelf',
#  "real-life 'lassie ' alerts humans to smoke",
#  "guitarist killer 's motive unknown",
#  'strategic games of atomic significance in iran',
#  'canon powershot a95',
#  'no-frills service could see prices drop',
#  "pakistan 's musharraf seeks islamic scholars ' help in terror fight",
#  'allen # 39 ; s absence suspends drama in sonics loss to lakers',
#  'sharon , now a dear old softy , can only detract from palestinian',
#  'treasury chief rejects idea of trying to stem dollar # 39 ; s fall',
#  'may-walsh beat mcpeak-youngs in olympic semis',
#  'j amp ; j # 39 ; s big buy',
#  'ichiro leads swingin # 39 ; singles in m # 39 ; s 7-3 win over angels',
#  'jackson joins kerry campaign as adviser',
#  "microsoft 's new music venture takes aim at apple itunes",
#  'csfb name may disappear : ceo',
#  'culture plays a role in dyslexia , scientists say',
#  'legal downloading reported down',
#  'linux and open source : the 2005 generation',
#  'when beethoven plays , it # 39 ; s time to take note of the bios',
#  'crashed capsule may still reveal solar secrets',
#  'thirty killed in gaza battle',
#  'allstate to reduce policies in florida',
#  'report : israel set to collide with eu',
#  "bush says he 's best protection from draft",
#  'killer typhoon swipes taiwan',
#  'ibm perks up memory , transistors',
#  'deutsche bank checked china aviation finances before share sale',
#  'palmone rings up new smartphone',
#  'stewart : martha seeks $ 3.7m in legal fees from namesake firm',
#  'rocketinfo partners with canadian press , helps nascar',
#  '3 palestinians killed in israeli incursion',
#  'fda eyes rules on child anti-depressants',
#  'in imphal , pm makes it a point to meet women who stripped to send',
#  'koizumi , silva discuss stronger ties',
#  'favre , tice can # 39 ; t help but admire their nfc north enemies',
#  'report : n. korea dismisses missile reports',
#  'defoe wants cole at spurs',
#  'the cigarette mafia',
#  'european spacecraft prepares to orbit moon',
#  'one standard , one microsoft - how the nhs sold its choice',
#  'santander gets approval of abbey bid',
#  'atlanta rallies to top dodgers',
#  'yahoo ! buys musicmatch for $ 160m',
#  'is the end nigh for opel ?',
#  'jetliner is first us one to land in vietnam since war # 39 ; s end',
#  'local chain rolling out d.c. tabloid',
#  'late-season heroics guide astros into playoffs',
#  'car bombs kill 24 , wound over 100 in iraq',
#  'giuliani said apologized to bush over kerik',
#  'putin tightens grip on regions and mps',
#  'indonesians set to go to polls',
#  'mcclaren pays for lack of ambition',
#  'pollution may be reducing calif. rainfall',
#  'the jets # 39 ; extra attention to tackling is paying off',
#  'firefox , bah humbug',
#  'australia fund buys gas stake in britain',
#  'doubleclick says quarterly profit more than doubles',
#  'itunes affiliate program',
#  'one nation finals are a big yawn',
#  'broken oxygen generator threatens space station',
#  'ailing pacers top ny',
#  'gop protesters refused use of central park',
#  'england fluff their lines at the last',
#  'explosion kills four in tel aviv market',
#  'google soars , shorts scramble to cover',
#  "bush praises colombia 's battle vs. drugs",
#  'golf : luke donald of england captures european masters',
#  'file sharing goes to high court',
#  'ea video game # 39 ; madden # 39 ; tops 1.3 million first week',
#  'lawyers file abu ghraib complaint',
#  'wachovia plans $ 400 million data center in birmingham',
#  'tokyo stocks turn lower on oil worries',
#  'u.n. wants stronger mandate for au monitors in darfur',
#  'two arrested in shooting death of idaho cornerback',
#  'kezman vows to hit the goal trail',
#  'vioxx recall draws attention to pfizer # 39 ; s celebrex',
#  'forest labs # 39 ; new hypertension drug disappoints in efficacy study',
#  'hp to tempt holiday shoppers with sights and sounds',
#  'pilots to try to retrieve genesis capsule',
#  "good news : 'phishing ' scams net & lt ; i & gt ; only & lt ; /i & gt ; $ 500 million",
#  'mass intelligence',
#  'miller hints that he # 39 ; ll retire after this season',
#  'restoration said may help gulf of maine',
#  'report : cendant near deal to buy orbitz',
#  "is xp 's fix safe ?",
#  'mississippi st. edges fairfield',
#  'taiwan calls for arms talks with china',
#  'palmsource embraces linux',
#  'oracle v. doj : oracle wins',
#  'how to play it straight',
#  'cramming features into phones',
#  'final opportunity',
#  'us # 39 ; snow cites quot ; shared responsibility quot ; to fight economic',
#  'quite a swing for daly-donofrio',
#  'cendant in talks to buy orbitz for $ 1 billion',
#  'hurricane center takes cues from florida state university',
#  'singh show not yet over for 2004',
#  'folgers lifts ground coffee prices 14',
#  'qwest reports $ 569 million loss in third quarter',
#  'an ivorian economy # 39 ; fatally hurt # 39 ;',
#  'group seeks ways to prosecute cybercrime',
#  'intel prepares for the next 20 years',
#  'japan pm readies cabinet reshuffle to silence critics',
#  'us team to search for remains of 2,000 soldiers in north korea',
#  'pennsylvania turnpike workers go on strike',
#  'cingular wireless fined $ 12.1 million over early termination fees',
#  "study : fill gov't science posts faster",
#  'ietf disbands anti-spam working group',
#  'chevrontexaco # 39 ; s 3q profit soars 62',
#  'the week in college football',
#  'rivalry voiced as libyan singer outpolls palestinian',
#  'u.s. official sees no n.korea talks before u.s. vote',
#  'riaa files 761 music lawsuits',
#  'accused acquitted of bali bombings',
#  'sprint thinks print with fujifilm partnership',
#  'yahoo ! partners with mark burnett for new season of # 39 ; the',
#  'apple to expand european itunes presence',
#  "s.korea 's ruling party head resigns on father 's past",
#  'transactions',
#  'us treasury report finds no forex manipulation',
#  'hopeful rangers make up ground',
#  'bush visits canada on fence-mending tour',
#  "knocking on heaven 's door",
#  'rocco dispirito is out at union pacific',
#  'wealth in america',
#  'human rights group have criticised hearings',
#  'japan quake victims sleep out',
#  'amazon offers discount to a9 search users',
#  'golf : vj shatters season earnings record',
#  'rare anti-mubarak demo in cairo',
#  'circulation drops will pull down ad revenue , analyst says',
#  'bradley caught way off base',
#  'palmone debuts treo 650 smartphone',
#  'ready for guard duty',
#  'billionaire club grows , forbes finds',
#  'passcode - secure id tags to fight hackers',
#  'google responds to google news china controversy',
#  'thursday # 39 ; s golf capsules',
#  'stelco gets $ 900m bid from bank',
#  'sf accuses paisley of holding gun to ahern and blair',
#  'update : tabcorp profit up , looks again at high rollers',
#  'jboss unveils workflow engine',
#  'beantown goes uptown',
#  'bush signs internet tax moratorium',
#  'stocks end barely higher',
#  'reese , meshiai lead champions tour quals',
#  'wake forest # 39 ; s chances could rest on player with # 39 ; cat burglar # 39 ;',
#  'kimberly-clark sets cost-cut plan',
#  'sybari offers security for im , sharepoint',
#  'new x prize sets sights on science , technology and social',
#  'spanish bank # 39 ; won # 39 ; t be put off by rival abbey bid # 39 ;',
#  'citigroup gets record fine for fund sales',
#  'kalam meets khalifa , offers condolences',
#  'musharraf to meet singh at the un',
#  'nato , russia to discuss school siege',
#  'late strike spoils christmas party for liverpool',
#  'time to dump ie ?',
#  'home computer land security',
#  'abbas to defend rights of palestinian refugees',
#  'firefox browser fully released',
#  'jeanne lashes dominican republic ; 9 dead',
#  'dimarco , riley play way into ryder cup',
#  'palestinians say israeli raids hampering renewal of peace talks',
#  'arsenal held to 1-1 tie by west brom',
#  'sports briefs november 12 , 2004',
#  'music publisher settles copyright skirmish over guthrie classic',
#  'berkshire hathaway',
#  'lots of points for top-tier nfl teams',
#  'men arrested as dutch religious tensions increase',
#  'dollar hits record euro low',
#  'big setback for merck cholesterol drug',
#  'disney pay-off case sets a precedent for us firms',
#  'no . 24 villanova 69 , penn 44',
#  'red cross gets first look at war-ravaged fallujah',
#  'taliban target cheney visit to karzai ceremony',
#  'ahold settles with dutch prosecutors',
#  'italian women freed',
#  'the rise of the bottomless hot water heaters',
#  '( sept. 12 , 2004 ) quick takes on some of week 1 # 39 ; s more',
#  "body of missing british tourist found near australia 's ayers rock",
#  'wenger ready to make petit a gunner again',
#  'miami , florida st. regrouping after storm',
#  'web surfing gets literal',
#  'mobiles get magnifier software',
#  "avaya agrees to buy germany 's tenovis",
#  "ea sees girl power boost with 'sims 2 ' sales",
#  'import prices rise less than expected',
#  'kashmir difficult issue , says powell',
#  'us envoy opposes kidnapper talks',
#  'harrington bags timely triumph',
#  'india rethinks plan for manned moon mission',
#  'commscope says costs rise , sales to fall',
#  'darfur aid groups fear fresh violence , move staff',
#  'stocks higher as profit worries ease',
#  'canon # 39 ; s digital delight',
#  'thailand urged to probe protesters # 39 ; deaths',
#  'itsa miracle one would part with a talisman',
#  'japanese co. markets dual-network phone',
#  'el guerrouj , holmes stride into olympic history',
#  'tigers reject sri lanka counter proposal to revive talks',
#  'cougars vow running game will have bite',
#  'u.s. strike targets in fallujah and tal afar',
#  'judge calls proposed shareholder settlement unfair',
#  'nuggets use twin powers to win',
#  'fury at cloning scientist # 39 ; s use of dna from the dead',
#  'update : woolworths profit up 12 ; ceo departure delayed',
#  'linux : fewer bugs than rivals',
#  'nl notables',
#  'exec says pentium m may add location-based services in 2006',
#  'kelly : perennial winner southwest in 14.1 traffic jump',
#  'future flyers : pushing forward for personal aircraft',
#  'world # 39 ; s tallest bridge will let drivers fly to the med',
#  'no . 10 arizona outguns wright st. 83-66',
#  'electronic eye devised to help blind cross roads',
#  "uk 's undersea 'ticking timebombs '",
#  'startup devises new way to squash worms',
#  'ldp to propose self-defense force',
#  'us trade gap shrinks to $ 51.6 billion',
#  'u.s. delays troops withdrawl from s. korea',
#  'un council ready to adopt new anti-terror measure',
#  'tendulkar , pathan give india scent of test win ( lead ) :',
#  'ethiopia accepts eritrea border ruling in principle',
#  'evolution and religion can coexist , scientists say',
#  'india sign off with a heartening victory',
#  'week in review : all eyes on ipod',
#  'us wants no warming proposal',
#  'judge calls conference on microsoft',
#  'israeli forces seize control of parts of north gaza',
#  'us in tech job massacre',
#  'profit up , ex-ceo out at scottsdale waste giant',
#  'is portable video ready for prime-time viewing ?',
#  'observers approve afghan election',
#  'vijay # 39 ; s has swing solution for tiger',
#  'digital contenders all hotshots',
#  'blast at shiite mosque in pakistan kills at least 10',
#  'yahoo ! unveils personal search beta',
#  'nigerian senate orders shell unit to pay',
#  'sch still expects to close abbey takeover by year end',
#  'vet and three children show no bird flu symptoms',
#  'three share lead at southern farm bureau classic',
#  'briton # 39 ; s kidnappers # 39 ; negotiating with afghan government # 39 ;',
#  'china mobile increases earnings 7.8',
#  'symantec to reinforce data protection',
#  's. korea warms to china as alternative to the us',
#  'woods # 39 ; lavish 1.5m wedding to model',
#  'typhoon forces 240,000 to flee',
#  'virgin announces plans for space service',
#  'consumer prices fall as gas costs drop',
#  'minn. woman , husband acquitted in mexico',
#  'paris club moves to write off iraq # 39 ; s debts',
#  'us watchdog investigates brokers',
#  'hfc bank in mass e-mail blunder',
#  'is priceline out of the cold ?',
#  'us vetoes un resolution on gaza offensive',
#  'microsoft windows ce beats palm os in pdas',
#  'babes in a grown-up toyland',
#  'hilton heading higher',
#  'oil near $ 50 on nigeria unease',
#  'nigerian oil delta rebel in 11th hour peace talks',
#  ...]

# %%
sentences = [titles[i]+" SEPTOKEN "+ texts[i] for i in range(len(titles))]

# %%
sent = sentences[0]
sent
# Out:
# 'oracle sex suit winner seeks $ 679,000 , apology SEPTOKEN it sales account manager in england seeks compensation after winning her sex discrimination case .'

# %%
sent2 = " ".join(sent)
# sent2.replace("  ", "SP")
sent2.replace("  S E P T O K E N  ", "SEPTOKEN").replace("   ", " SP ")
# Out:
# 'o r a c l e SP s e x SP s u i t SP w i n n e r SP s e e k s SP $ SP 6 7 9 , 0 0 0 SP , SP a p o l o g y SEPTOKEN i t SP s a l e s SP a c c o u n t SP m a n a g e r SP i n SP e n g l a n d SP s e e k s SP c o m p e n s a t i o n SP a f t e r SP w i n n i n g SP h e r SP s e x SP d i s c r i m i n a t i o n SP c a s e SP .'

# %%
for i in range(len(sentences)):
    sentences[i] = " ".join(sentences[i]).replace("  S E P T O K E N  ", "SEPTOKEN").replace("   ", " SP ")

# %%
sentences[:100]
# Out:
#  's y m b o l SP , SP p r o x i m SP s e t t l e SP w l a n SP p a t e n t SP c a s e SEPTOKEN s y m b o l SP t e c h n o l o g i e s SP a n d SP p r o x i m SP c o r p o r a t i o n SP s a i d SP t u e s d a y SP ( SP s e p t . SP 1 4 SP ) SP t h a t SP t h e y SP h a v e SP s e t t l e d SP a SP p a t e n t SP i n f r i n g e m e n t SP c a s e SP f o c u s i n g SP o n SP w i r e l e s s SP l a n SP ( SP w l a n SP ) SP t e c h n o l o g y SP .',
#  "a p p l e SP u n w r a p s SP n e w SP i m a c SP g 5 s SP a t SP p a r i s SP s h o w SEPTOKEN t h e SP n e w SP i m a c SP ' s SP s c r e e n SP i s SP s u s p e n d e d SP a b o v e SP t h e SP d e s k SP l i k e SP t h a t SP o f SP i t s SP p r e d e c e s s o r SP , SP b u t SP i t s SP p r o c e s s o r SP , SP h a r d SP d i s k SP a n d SP d v d SP d r i v e SP a r e SP c o n c e a l e d SP b e h i n d SP t h e SP s c r e e n SP r a t h e r SP t h a n SP i n SP t h e SP b a s e SP .",
#  'm o u n t SP s t . SP h e l e n s SP m a y SP t a k e SP w e e k s SP t o SP e r u p t SEPTOKEN m o u n t SP s t . SP h e l e n s SP s t e w e d SP i n SP v o l c a n i c SP g a s e s SP a n d SP l o w - l e v e l SP e a r t h q u a k e s SP s u n d a y SP , SP w i t h SP c r o w d s SP o f SP e a g e r SP t o u r i s t s SP h o p i n g SP t o SP g l i m p s e SP a n SP e r u p t i o n SP t h a t SP s c i e n t i s t s SP s a i d SP c o u l d SP h a p p e n SP i m m e d i a t e l y SP o r SP t a k e SP a SP f e w SP w e e k s SP .']

# %%
validation_sentences = sentences[:6000]
validation_labels = classes[:6000]

train_sentences = sentences[6000:120000]
train_labels = classes[6000:120000]

test_sentences = sentences[120000:]
test_labels = classes[120000:]

# %%
len(test_sentences)
# Out:
# 7600

# %%
import os

directory = ["ag_news_char_full", "ag_news_char_debug"]


for i in range(2):
    
    if i==1:
        train_sentences = train_sentences[:5000]
        train_labels = train_labels[:5000]
        validation_sentences = train_sentences[:5000]
        validation_labels = train_labels[:5000]
    
    name_dir = directory[i]
    if not os.path.exists(name_dir):
        os.makedirs(name_dir)

    with open(os.path.join(name_dir, "src_train.txt"), 'w') as f:
        for line in train_sentences:
            f.write(line+'\n')
        
    with open(os.path.join(name_dir, "src_val.txt"), 'w') as f:
        for line in validation_sentences:
            f.write(line+'\n')
        
    with open(os.path.join(name_dir, "tgt_train.txt"), 'w') as f:
        for line in train_labels:
            f.write(str(line)+'\n')
        
    with open(os.path.join(name_dir, "tgt_val.txt"), 'w') as f:
        for line in validation_labels:
            f.write(str(line)+'\n')

# %%
name_dir = "ag_news_char_full"

with open(os.path.join(name_dir, "src_test.txt"), 'w') as f:
    for line in test_sentences:
        f.write(line+'\n')

        
with open(os.path.join(name_dir, "tgt_test.txt"), 'w') as f:
    for line in test_labels:
        f.write(str(line)+'\n')
